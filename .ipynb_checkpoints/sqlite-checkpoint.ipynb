# %%
import sqlite3 
import pandas as pd

# %%
con=sqlite3.connect("DAERS.db")
con

# %%
cur = con.cursor()
cur

# %%
df = pd.read_sql_query("SELECT * from users join photos on photos.id==users.id", con)
df
# Out:
#       Id   UserName                                       PasswordHash  \
# 0      5   delacruz  b'{\xd1\xf9\xc7"$\x81\xbb\xf7\xdf!\x89\xdeQZ\x...
# 1      6  patterson  b'Z\xa11t\x13\x91\xf7H%\x96\x1eAy\xf19\xe2\xbb...
# 2      7    alvarez  b'\xdc\xe6\xa4\xb2\x88\xc9\x17\xb6\xcf\xa5MV\x...
# 3      8      tyler  b'\x86\x81\xc4\xe0\xd3\xf9\xd4K_E\xa3@\x9a\xa6...
# 4      9    puckett  b"\xa2\xafx\xd5\xb2\xe3\x90pe\xc9\x89Zhu\xf7\x...
# ..   ...        ...                                                ...
# 494  520     berger  b'\x8b\x82"\xb88\xac\xba\x8b\x14\xa7\xe5h\xc4\...
# 495  521      casey  b'(\x926R\xc8\x05\x8e\xc6:\xd9S\x95\x9a\xd9\x1...
# 496  522    miranda  b'\xce\x91v\xb0\x1f\x17\xd4\x1d+\x06\xb9,e1r\x...
# 497  523    lindsey  b'\xbc\xa3Or\xbe3\\\x90\xc6\xcd5`\x19\\D\xe4\x...
# 498  524      noman  b'\xea\x9a\xee\xa0d#\xf2\xdf\xd6\x95\xdd\x00,\...
#
#                                           PasswordSalt Gender  Age  \
# ...
