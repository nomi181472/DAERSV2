# %%
import pandas as pd
import numpy as np

# %%
#col=["Age","BMI","Waist","Total_Record","Label","With_Includes"]

# %%
#Original_df=pd.DataFrame(columns=col)
#Original_df=Original_df.append({"Age":18,"BMI":"BMI<18","Waist":"Waist<0","Total_Record":0,"Label":"N","With_Includes":"None"},ignore_index=True,)
#Original_df

# %%
#Original_df.to_csv("Data Information.csv", sep=',', index=False)

# %%
df=pd.read_csv("Data Information.csv",sep=",")
#df#
df
# Out:
#     Age        BMI       Waist Total_Record  \
# 0    18     BMI<18     Waist<0            0
# 1    18     BMI<18   Waist<0<3           20
# 2    18     BMI<18   Waist<3<8           20
# 3    18     BMI<18  Waist<8<12            0
# 4    18  BMI<18<25     Waist<0           20
# ..  ...        ...         ...          ...
# 57   45  BMI<25<30  Waist<8<12           50
# 58   45  BMI<18<25  Waist<8<12           50
# 59   45  BMI<30<35  Waist<8<12           50
# 60   45  BMI<30<35   Waist<3<8           50
# 61   45  BMI<30<35   Waist<3<8           50
#
#                                         With_Includes Label
# 0                                                None     N
# 1                                                None     N
# 2                                                None     M
# 3                                                None     0
# 4                                                None     N
# ..                                                ...   ...
# 57  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 58  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 59  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 60  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 61  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
#
# [62 rows x 6 columns]

# %%
#Data={"Age":60,"BMI":"BMI<18","Waist":"Waist<0","Total_Record":"-","Label":"N","With_Includes":"none"}

# %%
#df=df.append(Data,ignore_index=True)

#df=df.drop_duplicates()
df.groupby(by="Age").count()
# Out:
#      BMI  Waist  Label
# Age
# 18    16     16     16
# 30    15     15     15
# 45    15     15     15
# 60     6      6      6

# %%
df.to_csv("Data Information.csv", sep=',', index=False)
df=pd.read_csv("Data Information.csv",sep=",")

df
# Out:
#     Age        BMI       Waist Label
# 0    18     BMI<18     Waist<0     N
# 1    18     BMI<18   Waist<0<3     N
# 2    18     BMI<18   Waist<3<8     M
# 3    18     BMI<18  Waist<8<12     M
# 4    18  BMI<18<25     Waist<0     N
# 5    18  BMI<18<25   Waist<0<3     N
# 6    18  BMI<18<25   Waist<3<8     M
# 7    18  BMI<18<25  Waist<8<12     H
# 8    18  BMI<25<30     Waist<0     N
# 9    18  BMI<25<30   Waist<0<3     M
# 10   18  BMI<25<30   Waist<3<8     M
# 11   18  BMI<25<30  Waist<8<12     H
# 12   18  BMI<30<35     Waist<0     N
# 13   30  BMI<30<35     Waist<0     N
# 14   45  BMI<30<35     Waist<0     N
# 15   18  BMI<30<35   Waist<0<3     M
# 16   30  BMI<30<35   Waist<0<3     M
# 17   45  BMI<30<35   Waist<0<3     M
# 18   18  BMI<30<35   Waist<3<8     H
# 19   18  BMI<30<35  Waist<8<12     H
# 20   30  BMI<30<35   Waist<3<8     H
# 21   30  BMI<30<35  Waist<8<12     H
# 22   45  BMI<30<35   Waist<3<8     H
# 23   45  BMI<30<35  Waist<8<12     H
# 24   30     BMI<18     Waist<0     N
# 25   45     BMI<18     Waist<0     N
# 26   60     BMI<18     Waist<0     N
# 27   30  BMI<18<25     Waist<0     N
# 28   45  BMI<18<25     Waist<0     N
# 29   60  BMI<18<25     Waist<0     N
# 30   30  BMI<25<30     Waist<0     N
# 31   45  BMI<25<30     Waist<0     N
# 32   60  BMI<25<30     Waist<0     N
# 33   60  BMI<30<35     Waist<0     N
# 34   30     BMI<18   Waist<3<8     N
# 35   45     BMI<18   Waist<3<8     N
# 36   60     BMI<18   Waist<3<8     N
# 37   30     BMI<18  Waist<8<12     N
# 38   45     BMI<18  Waist<8<12     N
# 39   60     BMI<18  Waist<8<12     N
# 40   30  BMI<18<25   Waist<0<3     M
# 41   45  BMI<18<25   Waist<0<3     M
# 42   30  BMI<25<30   Waist<0<3     M
# 43   45  BMI<25<30   Waist<0<3     M
# 44   30  BMI<18<25   Waist<3<8     H
# 45   30  BMI<18<25  Waist<8<12     H
# 46   30  BMI<25<30   Waist<3<8     H
# 47   30  BMI<25<30  Waist<8<12     H
# 48   45  BMI<18<25   Waist<3<8     H
# 49   45  BMI<25<30   Waist<3<8     H
# 50   45  BMI<25<30  Waist<8<12     H
# 51   45  BMI<18<25  Waist<8<12     H

# %%
df.Age
# Out:
# 0     18
# 1     18
# 2     18
# 3     18
# 4     18
#       ..
# 57    45
# 58    45
# 59    45
# 60    45
# 61    45
# Name: Age, Length: 62, dtype: int64
