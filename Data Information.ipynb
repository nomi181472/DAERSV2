# %%
import pandas as pd
import numpy as np

# %%
#col=["Age","BMI","Waist","Total_Record","Label","With_Includes"]

# %%
#Original_df=pd.DataFrame(columns=col)
#Original_df=Original_df.append({"Age":18,"BMI":"BMI<18","Waist":"Waist<0","Total_Record":0,"Label":"N","With_Includes":"None"},ignore_index=True,)
#Original_df
# Out:
#   Age     BMI    Waist Total_Record With_Includes Label
# 0  18  BMI<18  Waist<0            0          None     N

# %%
#Original_df.to_csv("Data Information.csv", sep=',', index=False)

# %%
df=pd.read_csv("Data Information.csv",sep=",")
#df#
df
# Out:
#     Age        BMI       Waist Total_Record    With_Includes Label
# 0    18     BMI<18     Waist<0            0             None     N
# 1    18     BMI<18   Waist<0<3           20             None     N
# 2    18     BMI<18   Waist<3<8           20             None     M
# 3    18     BMI<18  Waist<8<12            0             None     0
# 4    18  BMI<18<25     Waist<0           20             None     N
# 5    18  BMI<18<25   Waist<0<3           20             None     N
# 6    18  BMI<18<25   Waist<3<8           20             None     M
# 7    18  BMI<18<25  Waist<8<12           20             None     H
# 8    18  BMI<25<30     Waist<0           20             None     N
# 9    18  BMI<25<30   Waist<0<3           20             None     M
# 10   18  BMI<25<30   Waist<3<8           20             None     M
# 11   18  BMI<25<30  Waist<8<12           20             None     H
# 12   18  BMI<30<35     Waist<0           50  age=18,30,45,60     N
# 13   30  BMI<30<35     Waist<0           50  age=18,30,45,60     N
# 14   45  BMI<30<35     Waist<0            -  age=18,30,45,60     N
# 15   45  BMI<30<35     Waist<0            -  age=18,30,45,60     N

# %%
Data={"Age":45,"BMI":"BMI<30<35","Waist":"Waist<8<12","Total_Record":"-","Label":"H","With_Includes":"waist=3to8,8to12;age=,18,30,45"}

# %%
df=df.append(Data,ignore_index=True)
df
# Out:
#     Age        BMI       Waist Total_Record                   With_Includes  \
# 0    18     BMI<18     Waist<0            0                            None
# 1    18     BMI<18   Waist<0<3           20                            None
# 2    18     BMI<18   Waist<3<8           20                            None
# 3    18     BMI<18  Waist<8<12            0                            None
# 4    18  BMI<18<25     Waist<0           20                            None
# 5    18  BMI<18<25   Waist<0<3           20                            None
# 6    18  BMI<18<25   Waist<3<8           20                            None
# 7    18  BMI<18<25  Waist<8<12           20                            None
# 8    18  BMI<25<30     Waist<0           20                            None
# 9    18  BMI<25<30   Waist<0<3           20                            None
# 10   18  BMI<25<30   Waist<3<8           20                            None
# 11   18  BMI<25<30  Waist<8<12           20                            None
# 12   18  BMI<30<35     Waist<0           50                 age=18,30,45,60
# 13   30  BMI<30<35     Waist<0           50                 age=18,30,45,60
# 14   45  BMI<30<35     Waist<0            -                 age=18,30,45,60
# 15   45  BMI<30<35     Waist<0            -                 age=18,30,45,60
# 16   18  BMI<30<35   Waist<0<3           40                    age=18,30,45
# 17   30  BMI<30<35   Waist<0<3            -                    age=18,30,45
# 18   45  BMI<30<35   Waist<0<3            -                    age=18,30,45
# 19   18  BMI<30<35   Waist<3<8           50  waist=3to8,8to12;age=,18,30,45
# 20   18  BMI<30<35  Waist<8<12            -  waist=3to8,8to12;age=,18,30,45
# 21   30  BMI<30<35   Waist<3<8            -  waist=3to8,8to12;age=,18,30,45
# 22   30  BMI<30<35  Waist<8<12            -  waist=3to8,8to12;age=,18,30,45
# 23   45  BMI<30<35   Waist<3<8            -  waist=3to8,8to12;age=,18,30,45
# 24   45  BMI<30<35  Waist<8<12            -  waist=3to8,8to12;age=,18,30,45
#
#    Label
# 0      N
# 1      N
# 2      M
# 3      0
# 4      N
# 5      N
# 6      M
# 7      H
# 8      N
# 9      M
# 10     M
# 11     H
# 12     N
# 13     N
# 14     N
# 15     N
# 16     M
# 17     M
# 18     M
# 19     H
# 20     H
# 21     H
# 22     H
# 23     H
# 24     H

# %%
df.to_csv("Data Information.csv", sep=',', index=False)
df=pd.read_csv("Data Information.csv",sep=",")

df
# Out:
#     Age        BMI       Waist Total_Record                   With_Includes  \
# 0    18     BMI<18     Waist<0            0                            None
# 1    18     BMI<18   Waist<0<3           20                            None
# 2    18     BMI<18   Waist<3<8           20                            None
# 3    18     BMI<18  Waist<8<12            0                            None
# 4    18  BMI<18<25     Waist<0           20                            None
# 5    18  BMI<18<25   Waist<0<3           20                            None
# 6    18  BMI<18<25   Waist<3<8           20                            None
# 7    18  BMI<18<25  Waist<8<12           20                            None
# 8    18  BMI<25<30     Waist<0           20                            None
# 9    18  BMI<25<30   Waist<0<3           20                            None
# 10   18  BMI<25<30   Waist<3<8           20                            None
# 11   18  BMI<25<30  Waist<8<12           20                            None
# 12   18  BMI<30<35     Waist<0           50                 age=18,30,45,60
# 13   30  BMI<30<35     Waist<0           50                 age=18,30,45,60
# 14   45  BMI<30<35     Waist<0            -                 age=18,30,45,60
# 15   45  BMI<30<35     Waist<0            -                 age=18,30,45,60
# 16   18  BMI<30<35   Waist<0<3           40                    age=18,30,45
# 17   30  BMI<30<35   Waist<0<3            -                    age=18,30,45
# 18   45  BMI<30<35   Waist<0<3            -                    age=18,30,45
# 19   18  BMI<30<35   Waist<3<8           50  waist=3to8,8to12;age=,18,30,45
# 20   18  BMI<30<35  Waist<8<12            -  waist=3to8,8to12;age=,18,30,45
# 21   30  BMI<30<35   Waist<3<8            -  waist=3to8,8to12;age=,18,30,45
# 22   30  BMI<30<35  Waist<8<12            -  waist=3to8,8to12;age=,18,30,45
# 23   45  BMI<30<35   Waist<3<8            -  waist=3to8,8to12;age=,18,30,45
# 24   45  BMI<30<35  Waist<8<12            -  waist=3to8,8to12;age=,18,30,45
#
#    Label
# 0      N
# 1      N
# 2      M
# 3      0
# 4      N
# 5      N
# 6      M
# 7      H
# 8      N
# 9      M
# 10     M
# 11     H
# 12     N
# 13     N
# 14     N
# 15     N
# 16     M
# 17     M
# 18     M
# 19     H
# 20     H
# 21     H
# 22     H
# 23     H
# 24     H
