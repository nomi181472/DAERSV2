# %%
import pandas as pd
import numpy as np

# %%
#col=["Age","BMI","Waist","Total_Record","Label","With_Includes"]

# %%
#Original_df=pd.DataFrame(columns=col)
#Original_df=Original_df.append({"Age":18,"BMI":"BMI<18","Waist":"Waist<0","Total_Record":0,"Label":"N","With_Includes":"None"},ignore_index=True,)
#Original_df
# Out:
#   Age     BMI    Waist Total_Record With_Includes Label
# 0  18  BMI<18  Waist<0            0          None     N

# %%
#Original_df.to_csv("Data Information.csv", sep=',', index=False)

# %%
df=pd.read_csv("Data Information.csv",sep=",")
#df#
df
# Out:
#     Age        BMI       Waist Total_Record  \
# 0    18     BMI<18     Waist<0            0
# 1    18     BMI<18   Waist<0<3           20
# 2    18     BMI<18   Waist<3<8           20
# 3    18     BMI<18  Waist<8<12            0
# 4    18  BMI<18<25     Waist<0           20
# ..  ...        ...         ...          ...
# 57   45  BMI<25<30  Waist<8<12           50
# 58   45  BMI<18<25  Waist<8<12           50
# 59   45  BMI<30<35  Waist<8<12           50
# 60   45  BMI<30<35   Waist<3<8           50
# 61   45  BMI<30<35   Waist<3<8           50
#
#                                         With_Includes Label
# 0                                                None     N
# 1                                                None     N
# 2                                                None     M
# 3                                                None     0
# 4                                                None     N
# ..                                                ...   ...
# 57  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 58  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 59  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 60  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 61  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
#
# [62 rows x 6 columns]

# %%
Data={"Age":60,"BMI":"BMI<18","Waist":"Waist<0","Total_Record":"-","Label":"N","With_Includes":"none"}

# %%
df=df.append(Data,ignore_index=True)
df[40:]
# Out:
#     Age        BMI       Waist Total_Record  \
# 40   30     BMI<18  Waist<8<12            -
# 41   45     BMI<18  Waist<8<12            -
# 42   60     BMI<18  Waist<8<12            -
# 43   30  BMI<18<25   Waist<0<3           30
# 44   45  BMI<18<25   Waist<0<3            -
# 45   30  BMI<25<30   Waist<0<3            -
# 46   45  BMI<25<30   Waist<0<3            -
# 47   30  BMI<30<35   Waist<0<3            -
# 48   45  BMI<30<35   Waist<0<3            -
# 49   30  BMI<18<25   Waist<3<8           50
# 50   30  BMI<18<25  Waist<8<12           50
# 51   30  BMI<25<30   Waist<3<8           50
# 52   30  BMI<25<30  Waist<8<12           50
# 53   30  BMI<30<35   Waist<3<8           50
# 54   30  BMI<30<35  Waist<8<12           50
# 55   45  BMI<18<25   Waist<3<8           50
# 56   45  BMI<25<30   Waist<3<8           50
# 57   45  BMI<25<30  Waist<8<12           50
# 58   45  BMI<18<25  Waist<8<12           50
# 59   45  BMI<30<35  Waist<8<12           50
# 60   45  BMI<30<35   Waist<3<8           50
# 61   45  BMI<30<35   Waist<3<8           50
# 62   60     BMI<18     Waist<0            -
#
#                                         With_Includes Label
# 40                                       age=30,45,60     -
# 41                                       age=30,45,60     -
# 42                                       age=30,45,60     -
# 43                 BMI=18to25,25to30,30to35;age=30,45     M
# 44                 BMI=18to25,25to30,30to35;age=30,45     M
# 45                 BMI=18to25,25to30,30to35;age=30,45     M
# 46                 BMI=18to25,25to30,30to35;age=30,45     M
# 47                 BMI=18to25,25to30,30to35;age=30,45     M
# 48                 BMI=18to25,25to30,30to35;age=30,45     M
# 49  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 50  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 51  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 52  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 53  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 54  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 55  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 56  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 57  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 58  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 59  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 60  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 61  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 62                                               none     N

# %%
df.to_csv("Data Information.csv", sep=',', index=False)
df=pd.read_csv("Data Information.csv",sep=",")

df
# Out:
#     Age        BMI       Waist Total_Record  \
# 0    18     BMI<18     Waist<0            0
# 1    18     BMI<18   Waist<0<3           20
# 2    18     BMI<18   Waist<3<8           20
# 3    18     BMI<18  Waist<8<12            0
# 4    18  BMI<18<25     Waist<0           20
# ..  ...        ...         ...          ...
# 57   45  BMI<25<30  Waist<8<12           50
# 58   45  BMI<18<25  Waist<8<12           50
# 59   45  BMI<30<35  Waist<8<12           50
# 60   45  BMI<30<35   Waist<3<8           50
# 61   45  BMI<30<35   Waist<3<8           50
#
#                                         With_Includes Label
# 0                                                None     N
# 1                                                None     N
# 2                                                None     M
# 3                                                None     0
# 4                                                None     N
# ..                                                ...   ...
# 57  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 58  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 59  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 60  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
# 61  Waist=3to8,8to12;BMI=18to25,25to30,30to35;age=...     H
#
# [62 rows x 6 columns]

# %%
df.Age
# Out:
# 0     18
# 1     18
# 2     18
# 3     18
# 4     18
#       ..
# 57    45
# 58    45
# 59    45
# 60    45
# 61    45
# Name: Age, Length: 62, dtype: int64
